# %%
import pandas as pd

# %%
df = pd.read_csv('KPHL.csv', index_col = 'date')
#data set obtained from fivethirtyeight (see url below)
#https://github.com/fivethirtyeight/data/blob/master/us-weather-history/KPHL.csv

# %%
df.head()
# Out:
#           actual_mean_temp  actual_min_temp  actual_max_temp  \
# date
# 2014-7-1                83               72               93
# 2014-7-2                86               75               96
# 2014-7-3                83               74               92
# 2014-7-4                73               68               78
# 2014-7-5                74               64               83
#
#           average_min_temp  average_max_temp  record_min_temp  \
# date
# 2014-7-1                68                86               52
# 2014-7-2                68                86               52
# 2014-7-3                68                87               54
# 2014-7-4                68                87               52
# 2014-7-5                69                87               55
#
#           record_max_temp  record_min_temp_year  record_max_temp_year  \
# date
# 2014-7-1              102                  1988                  1901
# ...

# %%
df.rename(columns = {'actual_mean_temp': 'mean_temp', 'actual_min_temp': 'min_temp', 'actual_max_temp': 'max_temp'})
# Out:
#            mean_temp  min_temp  max_temp  average_min_temp  average_max_temp  \
# date
# 2014-7-1          83        72        93                68                86
# 2014-7-2          86        75        96                68                86
# 2014-7-3          83        74        92                68                87
# 2014-7-4          73        68        78                68                87
# 2014-7-5          74        64        83                69                87
# ...              ...       ...       ...               ...               ...
# 2015-6-26         76        68        84                67                85
# 2015-6-27         67        63        71                67                86
# 2015-6-28         73        66        79                67                86
# 2015-6-29         72        63        81                68                86
# 2015-6-30         77        67        86                68                86
#
# ...

# %%
df.describe()
# Out:
#        actual_mean_temp  actual_min_temp  actual_max_temp  average_min_temp  \
# count        365.000000       365.000000       365.000000        365.000000
# mean          55.884932        47.265753        63.983562         47.221918
# std           18.947380        18.391740        19.886070         15.454917
# min           10.000000         2.000000        17.000000         25.000000
# 25%           39.000000        33.000000        46.000000         32.000000
# 50%           59.000000        50.000000        69.000000         46.000000
# 75%           73.000000        64.000000        82.000000         63.000000
# max           86.000000        77.000000        96.000000         70.000000
#
#        average_max_temp  record_min_temp  record_max_temp  \
# count        365.000000       365.000000       365.000000
# mean          64.723288        28.030137        84.989041
# std           16.432768        19.379854        12.556242
# ...

# %%
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'actual_mean_temp'}>,
#         <AxesSubplot:title={'center':'actual_min_temp'}>,
#         <AxesSubplot:title={'center':'actual_max_temp'}>],
#        [<AxesSubplot:title={'center':'average_min_temp'}>,
#         <AxesSubplot:title={'center':'average_max_temp'}>,
#         <AxesSubplot:title={'center':'record_min_temp'}>],
#        [<AxesSubplot:title={'center':'record_max_temp'}>,
#         <AxesSubplot:title={'center':'record_min_temp_year'}>,
#         <AxesSubplot:title={'center':'record_max_temp_year'}>],
#        [<AxesSubplot:title={'center':'actual_precipitation'}>,
#         <AxesSubplot:title={'center':'average_precipitation'}>,
#         <AxesSubplot:title={'center':'record_precipitation'}>]],
#       dtype=object)
